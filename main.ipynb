# %%
import requests
import bs4

# %%
with open("aktualne.html", encoding="utf-8") as website:
    soup = bs4.BeautifulSoup(website, "html.parser")

# %%
tag_a = soup.a

# %%
type(tag_a)
# Out:
# bs4.element.Tag

# %%
tag_a['href']
# Out:
# 'http://www.pkn.pl/'

# %%
tag_a.attrs
# Out:
# {'href': 'http://www.pkn.pl/', 'target': '_blank'}

# %%
soup.a['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-219e5e12a60e> in <module>
# ----> 1 soup.a['class']
#
# c:\users\nowakf\appdata\local\programs\python\python37-32\lib\site-packages\bs4\element.py in __getitem__(self, key)
#     969         """tag[key] returns the value of the 'key' attribute for the tag,
#     970         and throws an exception if it's not there."""
# --> 971         return self.attrs[key]
#     972
#     973     def __iter__(self):
#
# KeyError: 'class'

# %%
soup.find_all("a", class_="p4s-search-results-link")
# Out:
# [<a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+31%2BA1%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 31+A1:2014-07
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+31%2BA1%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Umywalki -- Wymiary przyłączeniowe
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+31%2BA1%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Wash basins -- Connecting dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+31%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 31:2011
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+33%3A2019-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 33:2019-06
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+33%3A2019-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Miski ustępowe i zestawy WC -- Wymiary przyłączeniowe
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+33%3A2019-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					WC pans and WC suites -- Connecting dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+33%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 33:2011
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+33%3A2011%2FAC%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 33:2011/AC:2014-07
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+35%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 35:2014-07
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+35%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Stojące i podwieszane bidety zasilane od góry -- Wymiary przyłączeniowe
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+35%3A2014-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Pedestal and wall-hung bidets with over-rim supply -- Connecting dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+35%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 35:2001
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+36%3A2000P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 36:2000
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+36%3A2000%2FAp1%3A2003P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 36:2000/Ap1:2003
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-1:2002
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Terminy i definicje
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 1: Definitions and terms
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002D&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-1:2002
#  				<span style="margin-left: 10px;">
#  					wersja niemiecka
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002D&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Terminy i definicje
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-1%3A2002D&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 1: Definitions and terms
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-2:2005
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 2: Wymagania ogólne i wymiary
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 2: General requirements and dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-2:2002
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-2%3A2005%2FAp1%3A2006P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-2:2005/Ap1:2006 wersja polska</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-2%3A2005%2FAp1%3A2006P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  				Słupy oświetleniowe -- Część 2: Wymagania ogólne i wymiary
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-2%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-2%3A2005%2FAp1%3A2006P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  					Lighting columns - Part 2: General requirements and dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-1:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-1: Projektowanie i weryfikacja -- Obciążenia charakterystyczne
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns -- Part 3-1: Design and verification - Specification for characteristic loads
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-1:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-1:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-1: Projektowanie i weryfikacja -- Specyfikacja obciążeń charakterystycznych
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 3-1: Design and verification - Specification for characteristic loads
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-1:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-3-1%3A2013-06%2FAp1%3A2014-08E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-1:2013-06/Ap1:2014-08 wersja angielska</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-3-1%3A2013-06%2FAp1%3A2014-08E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  				Słupy oświetleniowe -- Część 3-1: Projektowanie i weryfikacja -- Specyfikacja obciążeń charakterystycznych
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-1%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardEdNumber=PN-EN+40-3-1%3A2013-06%2FAp1%3A2014-08E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showElementDodatkowyDetailsAction">
#  					Lighting columns -- Part 3-1: Design and verification - Specification for characteristic loads
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-2:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-2: Projektowanie i weryfikacja -- Weryfikacja za pomocą badań
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns -- Part 3-2: Design and verification - Verification by testing
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-2:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-2:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-2: Projektowanie i weryfikacja -- Weryfikacja za pomocą badań
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 3-2: Design and verification -  Verification by testing
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-2%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-2:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-3:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-3: Projektowanie i weryfikacja -- Weryfikacja za pomocą obliczeń
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns -- Part 3-3: Design and verification - Verification by calculation
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-3:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-3-3:2013-06
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 3-3: Projektowanie i weryfikacja -- Weryfikacja za pomocą obliczeń
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2013-06E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 3-3: Design and verification - Verification by calculation
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-3-3%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-3-3:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-4%3A2008P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-4:2008
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-4%3A2008P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 4: Wymagania dotyczące słupów oświetleniowych z betonu zbrojonego i sprężonego
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-4%3A2008P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 4: Requirements for reinforced and prestressed concrete lighting columns
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-4%3A2006E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-4:2006
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-4%3A2006%2FAC%3A2006E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-4:2006/AC:2006
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-5%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-5:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-5%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 5: Słupy oświetleniowe stalowe -- Wymagania
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-5%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 5: Requirements for steel lighting columns
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-5%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-5:2002
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-6%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-6:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-6%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 6: Słupy oświetleniowe aluminiowe -- Wymagania
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-6%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 6: Requirements for aluminium lighting columns
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-6%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 40-6:2002
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-7%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 40-7:2004
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-7%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Słupy oświetleniowe -- Część 7: Słupy oświetleniowe z kompozytów polimerowych wzmocnionych włóknem szklanym -- Wymagania
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+40-7%3A2004P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Lighting columns - Part 7: Requirements for fibre reinforced polymer composite lighting columns
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+80%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 80:2002
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+80%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Pisuary naścienne -- Wymiary przyłączeniowe
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+80%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Wall-hung urinals - Connecting dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+107%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 107:2002
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+107%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań okien -- Badania mechaniczne
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+107%3A2002E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of testing windows - Mechanical test
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+124-1%3A2015-07P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 124-1:2015-07
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+124-1%3A2015-07P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
# ...
#  					Methods of test for masonry units - Part 11: Determination of water absorption of aggregate concrete, autoclaved aerated concrete, manufactured stone and natural stone masonry units due to capillary action and the initial rate of water absorption of clay masonry units
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-11%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 772-11:2002
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-11%3A2002%2FA1%3A2005P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 772-11:2002/A1:2005
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-13%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-13:2001
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-13%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 13: Określenie gęstości netto i gęstości brutto elementów murowych w stanie suchym (z wyjątkiem kamienia naturalnego)
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-13%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units - Part 13: Determination of net and gross dry density of masonry units (except for natural stone)
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-14%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-14:2002
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-14%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 14: Określenie zmian liniowych pod wpływem wilgoci elementów murowych z betonu kruszywowego i kamienia sztucznego
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-14%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units - Part 14: Determination of moisture movement of aggregate concrete and manufactured stone masonry units
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-15%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-15:2002
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-15%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 15: Oznaczanie współczynnika przepuszczania pary wodnej elementów murowych z autoklawizowanego betonu komórkowego
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-15%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units - Part 15: Determination of water vapour permeability of autoclaved aerated concrete masonry units
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-16:2011
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 16: Określenie wymiarów
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units -- Part 16: Determination of dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2006P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 772-16:2006
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-16:2011
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 16: Określenie wymiarów
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units - Part 16: Determination of dimensions
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-16%3A2006P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 772-16:2006
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-18%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-18:2011
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-18%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 18: Określenie odporności na zamrażanie-odmrażanie elementów murowych silikatowych
#  			</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-18%3A2011E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Methods of test for masonry units - Part 18: Determination of freeze-thaw resistance of calcium silicate masonry units
#  				</a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-18%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 772-18:2001
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-19%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 772-19:2002
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a>,
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+772-19%3A2002P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Metody badań elementów murowych -- Część 19: Określenie rozszerzalności pod wpływem wilgoci dużych, poziomo drążonych elementów murowych ceramicznych
#  			</a>,
#  ...]

# %%
type(soup.find_all("a", class_="p4s-search-results-link"))
# Out:
# bs4.element.ResultSet

# %%
type(tag_a.string)
# Out:
# NoneType

# %%
soup.title
# Out:
# <title>Wyszukiwarka norm - WIEDZA</title>

# %%
soup.a
# Out:
# <a href="http://www.pkn.pl/" target="_blank"><img alt="PKN" src="./aktualne_files/pknLogo.png"/></a>

# %%
soup.a.contents
# Out:
# [<img alt="PKN" src="./aktualne_files/pknLogo.png"/>]

# %%
soup.a.children

# %%
soup.a.descendants
# Out:
# <generator object Tag.descendants at 0x11AEC9F0>

# %%
for d in soup.a.descendants:
    print(d)
# Out:
# <img alt="PKN" src="./aktualne_files/pknLogo.png"/>

# %%
len(list(soup.descendants))
# Out:
# 260771

# %%
lista = []
for match in soup.find_all("span", class_="highlighted-search-term"):
    lista.append(match.next_sibling)
lista
# Out:
# ['-EN 31+A1:2014-07\n\t\t\t\t',
#  '-EN 33:2019-06\n\t\t\t\t',
#  '-EN 35:2014-07\n\t\t\t\t',
#  '-EN 40-1:2002\n\t\t\t\t',
#  '-EN 40-1:2002\n\t\t\t\t',
#  '-EN 40-2:2005\n\t\t\t\t',
#  '-EN 40-2:2005/Ap1:2006 wersja polska',
#  '-EN 40-3-1:2013-06\n\t\t\t\t',
#  '-EN 40-3-1:2013-06\n\t\t\t\t',
#  '-EN 40-3-1:2013-06/Ap1:2014-08 wersja angielska',
#  '-EN 40-3-2:2013-06\n\t\t\t\t',
#  '-EN 40-3-2:2013-06\n\t\t\t\t',
#  '-EN 40-3-3:2013-06\n\t\t\t\t',
#  '-EN 40-3-3:2013-06\n\t\t\t\t',
#  '-EN 40-4:2008\n\t\t\t\t',
#  '-EN 40-5:2004\n\t\t\t\t',
#  '-EN 40-6:2004\n\t\t\t\t',
#  '-EN 40-7:2004\n\t\t\t\t',
#  '-EN 80:2002\n\t\t\t\t',
#  '-EN 107:2002\n\t\t\t\t',
#  '-EN 124-1:2015-07\n\t\t\t\t',
#  '-EN 124-1:2015-07\n\t\t\t\t',
#  '-EN 124-1:2015-07/Ap1:2016-07 wersja angielska',
#  '-EN 124-2:2015-07\n\t\t\t\t',
#  '-EN 124-2:2015-07\n\t\t\t\t',
#  '-EN 124-2:2015-07/Ap1:2017-07 wersja angielska',
#  '-EN 124-3:2015-07\n\t\t\t\t',
#  '-EN 124-3:2015-07\n\t\t\t\t',
#  '-EN 124-3:2015-07/Ap1:2017-08 wersja angielska',
#  '-EN 124-4:2015-07\n\t\t\t\t',
#  '-EN 124-4:2015-07\n\t\t\t\t',
#  '-EN 124-4:2015-07/Ap1:2017-08 wersja angielska',
#  '-EN 124-5:2015-07\n\t\t\t\t',
#  '-EN 124-5:2015-07\n\t\t\t\t',
#  '-EN 124-5:2015-07/Ap1:2017-08 wersja angielska',
#  '-EN 124-6:2015-07\n\t\t\t\t',
#  '-EN 124-6:2015-07\n\t\t\t\t',
#  '-EN 124-6:2015-07/Ap1:2017-08 wersja angielska',
#  '-EN 130:1998\n\t\t\t\t',
#  '-EN 179:2009\n\t\t\t\t',
#  '-EN 196-1:2016-07\n\t\t\t\t',
#  '-EN 196-1:2016-07\n\t\t\t\t',
#  '-EN 196-2:2013-11\n\t\t\t\t',
#  '-EN 196-2:2013-11\n\t\t\t\t',
#  '-EN 196-3:2016-12\n\t\t\t\t',
#  '-EN 196-3:2016-12\n\t\t\t\t',
#  '-EN 196-5:2011\n\t\t\t\t',
#  '-EN 196-5:2011\n\t\t\t\t',
#  '-EN 196-6:2019-01\n\t\t\t\t',
#  '-EN 196-7:2009\n\t\t\t\t',
#  '-EN 196-8:2010\n\t\t\t\t',
#  '-EN 196-9:2010\n\t\t\t\t',
#  '-EN 196-10:2016-07\n\t\t\t\t',
#  '-EN 196-10:2016-07\n\t\t\t\t',
#  '-EN 196-11:2019-01\n\t\t\t\t',
#  '-EN 197-1:2012\n\t\t\t\t',
#  '-EN 197-1:2012\n\t\t\t\t',
#  '-EN 197-1:2012\n\t\t\t\t',
#  '-EN 197-2:2014-05\n\t\t\t\t',
#  '-EN 197-2:2014-05\n\t\t\t\t',
#  '-EN 198:2008\n\t\t\t\t',
#  '-EN 198:2008\n\t\t\t\t',
#  '-EN 200:2008\n\t\t\t\t',
#  '-EN 200:2008\n\t\t\t\t',
#  '-EN 206+A1:2016-12\n\t\t\t\t',
#  '-EN 206+A1:2016-12\n\t\t\t\t',
#  '-EN 215:2005\n\t\t\t\t',
#  '-EN 215:2005/A1:2006 wersja angielska',
#  '-EN 232:2013-04\n\t\t\t\t',
#  '-EN 246:2005\n\t\t\t\t',
#  '-EN 248:2005\n\t\t\t\t',
#  '-EN 249:2010\n\t\t\t\t',
#  '-EN 251:2013-04\n\t\t\t\t',
#  '-EN 253+A2:2015-12\n\t\t\t\t',
#  '-EN 253+A2:2015-12\n\t\t\t\t',
#  '-EN 263:2008\n\t\t\t\t',
#  '-EN 274-1:2004\n\t\t\t\t',
#  '-EN 274-1:2004/Ap1:2012 wersja polska',
#  '-EN 274-2:2004\n\t\t\t\t',
#  '-EN 274-3:2004\n\t\t\t\t',
#  '-EN 295-1:2013-06\n\t\t\t\t',
#  '-EN 295-1:2013-06/Ap1:2013-07 wersja angielska',
#  '-EN 295-2:2013-07\n\t\t\t\t',
#  '-EN 295-3:2012\n\t\t\t\t',
#  '-EN 295-4:2013-07\n\t\t\t\t',
#  '-EN 295-5:2013-07\n\t\t\t\t',
#  '-EN 295-6:2013-07\n\t\t\t\t',
#  '-EN 295-7:2013-07\n\t\t\t\t',
#  '-EN 303-1:2017-10\n\t\t\t\t',
#  '-EN 303-2:2017-09\n\t\t\t\t',
#  '-EN 303-3:2002\n\t\t\t\t',
#  '-EN 303-3:2002/AC:2007 wersja polska',
#  '-EN 303-3:2002/A2:2005 wersja polska',
#  '-EN 303-4:2002\n\t\t\t\t',
#  '-EN 303-5:2012\n\t\t\t\t',
#  '-EN 303-5:2012\n\t\t\t\t',
#  '-EN 303-5:2012\n\t\t\t\t',
#  '-EN 303-6:2002\n\t\t\t\t',
#  '-EN 303-7:2008\n\t\t\t\t',
#  '-EN 304:2017-11\n\t\t\t\t',
#  '-EN 336:2013-12\n\t\t\t\t',
#  '-EN 338:2016-06\n\t\t\t\t',
#  '-EN 356:2000\n\t\t\t\t',
#  '-EN 380:1998\n\t\t\t\t',
#  '-EN 383:2007\n\t\t\t\t',
#  '-EN 384+A1:2018-12\n\t\t\t\t',
#  '-EN 408+A1:2012\n\t\t\t\t',
#  '-EN 409:2009\n\t\t\t\t',
#  '-EN 410:2011\n\t\t\t\t',
#  '-EN 410:2011\n\t\t\t\t',
#  '-EN 410:2011/Ap1:2013-07 wersja angielska',
#  '-EN 413-1:2011\n\t\t\t\t',
#  '-EN 413-1:2011\n\t\t\t\t',
#  '-EN 413-2:2016-11\n\t\t\t\t',
#  '-EN 442-1:2015-02\n\t\t\t\t',
#  '-EN 442-1:2015-02/Ap1:2018-05 wersja polska',
#  '-EN 442-1:2015-02\n\t\t\t\t',
#  '-EN 442-2:2015-02\n\t\t\t\t',
#  '-EN 442-2:2015-02\n\t\t\t\t',
#  '-EN 445:2009\n\t\t\t\t',
#  '-EN 446:2009\n\t\t\t\t',
#  '-EN 447:2009\n\t\t\t\t',
#  '-EN 448:2015-12\n\t\t\t\t',
#  '-EN 448:2015-12\n\t\t\t\t',
#  '-EN 450-1:2012\n\t\t\t\t',
#  '-EN 450-1:2012\n\t\t\t\t',
#  '-EN 450-2:2006\n\t\t\t\t',
#  '-EN 451-1:2017-06\n\t\t\t\t',
#  '-EN 451-2:2017-06\n\t\t\t\t',
#  '-EN 459-1:2015-06\n\t\t\t\t',
#  '-EN 459-1:2015-06\n\t\t\t\t',
#  '-EN 459-2:2010\n\t\t\t\t',
#  '-EN 459-2:2010\n\t\t\t\t',
#  '-EN 459-2:2010\n\t\t\t\t',
#  '-EN 459-3:2015-06\n\t\t\t\t',
#  '-EN 459-3:2015-06\n\t\t\t\t',
#  '-EN 476:2012\n\t\t\t\t',
#  '-EN 480-1:2014-12\n\t\t\t\t',
#  '-EN 480-2:2008\n\t\t\t\t',
#  '-EN 480-4:2008\n\t\t\t\t',
#  '-EN 480-5:2008\n\t\t\t\t',
#  '-EN 480-6:2008\n\t\t\t\t',
#  '-EN 480-8:2012\n\t\t\t\t',
#  '-EN 480-10:2011\n\t\t\t\t',
#  '-EN 480-11:2008\n\t\t\t\t',
#  '-EN 480-12:2008\n\t\t\t\t',
#  '-EN 480-13:2015-08\n\t\t\t\t',
#  '-EN 480-14:2008\n\t\t\t\t',
#  '-EN 480-15:2013-07\n\t\t\t\t',
#  '-EN 488:2015-12\n\t\t\t\t',
#  '-EN 488:2015-12\n\t\t\t\t',
#  '-EN 489:2009\n\t\t\t\t',
#  '-EN 490+A1:2017-02\n\t\t\t\t',
#  '-EN 491:2012\n\t\t\t\t',
#  '-EN 492+A2:2018-06\n\t\t\t\t',
#  '-EN 494+A1:2015-11\n\t\t\t\t',
#  '-EN 494+A1:2015-11\n\t\t\t\t',
#  '-EN 495-5:2013-07\n\t\t\t\t',
#  '-EN 501:1999\n\t\t\t\t',
#  '-EN 502:2013-07\n\t\t\t\t',
#  '-EN 504:2002\n\t\t\t\t',
#  '-EN 505:2013-07\n\t\t\t\t',
#  '-EN 506:2010\n\t\t\t\t',
#  '-EN 507:2002\n\t\t\t\t',
#  '-EN 508-1:2014-08\n\t\t\t\t',
#  '-EN 508-2:2010\n\t\t\t\t',
#  '-EN 508-3:2010\n\t\t\t\t',
#  '-EN 512:2000\n\t\t\t\t',
#  '-EN 512:2000/A1:2002 wersja polska',
#  '-EN 516:2007\n\t\t\t\t',
#  '-EN 517:2007\n\t\t\t\t',
#  '-EN 520+A1:2012\n\t\t\t\t',
#  '-EN 523:2004\n\t\t\t\t',
#  '-EN 524-1:1999\n\t\t\t\t',
#  '-EN 524-2:1999\n\t\t\t\t',
#  '-EN 524-3:1999\n\t\t\t\t',
#  '-EN 524-4:1999\n\t\t\t\t',
#  '-EN 524-5:1999\n\t\t\t\t',
#  '-EN 524-6:1999\n\t\t\t\t',
#  '-EN 534+A1:2010\n\t\t\t\t',
#  '-EN 538:1999\n\t\t\t\t',
#  '-EN 539-1:2007\n\t\t\t\t',
#  '-EN 539-2:2013-07\n\t\t\t\t',
#  '-EN 544:2011\n\t\t\t\t',
#  '-EN 545:2010\n\t\t\t\t',
#  '-EN 572-1+A1:2016-03\n\t\t\t\t',
#  '-EN 572-2:2012\n\t\t\t\t',
#  '-EN 572-2:2012\n\t\t\t\t',
#  '-EN 572-3:2012\n\t\t\t\t',
#  '-EN 572-4:2012\n\t\t\t\t',
#  '-EN 572-5:2012\n\t\t\t\t',
#  '-EN 572-5:2012\n\t\t\t\t',
#  '-EN 572-5:2012/Ap1:2014-11 wersja angielska',
#  '-EN 572-6:2012\n\t\t\t\t',
#  '-EN 572-7:2012\n\t\t\t\t',
#  '-EN 572-8+A1:2016-03\n\t\t\t\t',
#  '-EN 572-8+A1:2016-03\n\t\t\t\t',
#  '-EN 572-8+A1:2016-03/Ap1:2018-08 wersja angielska',
#  '-EN 572-9:2006\n\t\t\t\t',
#  '-EN 572-9:2006/Ap1:2007 wersja polska',
#  '-EN 588-1:2000\n\t\t\t\t',
#  '-EN 588-2:2004\n\t\t\t\t',
#  '-EN 594:2011\n\t\t\t\t',
#  '-EN 595:1998\n\t\t\t\t',
#  '-EN 596:1999\n\t\t\t\t',
#  '-EN 598+A1:2010\n\t\t\t\t',
#  '-EN 607:2005\n\t\t\t\t',
#  '-EN 612:2006\n\t\t\t\t',
#  '-EN 639:1999\n\t\t\t\t',
#  '-EN 640:2000\n\t\t\t\t',
#  '-EN 641:2000\n\t\t\t\t',
#  '-EN 642:2000\n\t\t\t\t',
#  '-EN 673:2011\n\t\t\t\t',
#  '-EN 674:2011\n\t\t\t\t',
#  '-EN 675:2011\n\t\t\t\t',
#  '-EN 678:1998\n\t\t\t\t',
#  '-EN 679:2008\n\t\t\t\t',
#  '-EN 680:2008\n\t\t\t\t',
#  '-EN 695:2005\n\t\t\t\t',
#  '-EN 752:2017-06\n\t\t\t\t',
#  '-EN 771-1+A1:2015-10\n\t\t\t\t',
#  '-EN 771-1+A1:2015-10/Ap1:2018-08 wersja angielska',
#  '-EN 771-2+A1:2015-10\n\t\t\t\t',
#  '-EN 771-2+A1:2015-10\n\t\t\t\t',
#  '-EN 771-3+A1:2015-10\n\t\t\t\t',
#  '-EN 771-4+A1:2015-10\n\t\t\t\t',
#  '-EN 771-4+A1:2015-10\n\t\t\t\t',
#  '-EN 771-4+A1:2015-10/Ap1:2016-12 wersja angielska',
#  '-EN 771-5+A1:2015-10\n\t\t\t\t',
#  '-EN 771-6+A1:2015-10\n\t\t\t\t',
#  '-EN 772-1+A1:2015-10\n\t\t\t\t',
#  '-EN 772-2:2006\n\t\t\t\t',
#  '-EN 772-3:2000\n\t\t\t\t',
#  '-EN 772-4:2001\n\t\t\t\t',
#  '-EN 772-5:2016-06\n\t\t\t\t',
#  '-EN 772-5:2016-06/AC:2017-08 wersja angielska',
#  '-EN 772-6:2002\n\t\t\t\t',
#  '-EN 772-7:2000\n\t\t\t\t',
#  '-EN 772-9:2006\n\t\t\t\t',
#  '-EN 772-10:2000\n\t\t\t\t',
#  '-EN 772-11:2011\n\t\t\t\t',
#  '-EN 772-13:2001\n\t\t\t\t',
#  '-EN 772-14:2002\n\t\t\t\t',
#  '-EN 772-15:2002\n\t\t\t\t',
#  '-EN 772-16:2011\n\t\t\t\t',
#  '-EN 772-16:2011\n\t\t\t\t',
#  '-EN 772-18:2011\n\t\t\t\t',
#  '-EN 772-19:2002\n\t\t\t\t',
#  '-EN 772-20:2002\n\t\t\t\t',
#  '-EN 772-20:2002/A1:2005 wersja angielska',
#  '-EN 772-21:2011\n\t\t\t\t',
#  '-EN 772-22:2019-01\n\t\t\t\t',
#  '-EN 789:2005\n\t\t\t\t',
#  '-EN 805:2002\n\t\t\t\t',
#  '-EN 805:2002/Ap1:2006 wersja polska',
#  '-EN 806-1:2004\n\t\t\t\t',
#  '-EN 806-2:2005\n\t\t\t\t',
#  '-EN 806-3:2006\n\t\t\t\t',
#  '-EN 806-4:2010\n\t\t\t\t',
#  '-EN 806-5:2012\n\t\t\t\t',
#  '-EN 816:2017-09\n\t\t\t\t',
#  '-EN 817:2008\n\t\t\t\t',
#  '-EN 822:2013-07\n\t\t\t\t',
#  '-EN 823:2013-07\n\t\t\t\t',
#  '-EN 824:2013-07\n\t\t\t\t',
#  '-EN 825:2013-07\n\t\t\t\t',
#  '-EN 826:2013-07\n\t\t\t\t',
#  '-EN 834:2013-12\n\t\t\t\t',
#  '-EN 834:2013-12/AC:2015-07 wersja angielska',
#  '-EN 835:1999\n\t\t\t\t',
#  '-EN 835:1999/Ap1:2004 wersja polska',
#  '-EN 845-1+A1:2016-10\n\t\t\t\t',
#  '-EN 845-2+A1:2016-10\n\t\t\t\t',
#  '-EN 845-3+A1:2016-10\n\t\t\t\t',
#  '-EN 846-2:2002\n\t\t\t\t',
#  '-EN 846-3:2002\n\t\t\t\t',
#  '-EN 846-4:2003\n\t\t\t\t',
#  '-EN 846-4:2003/A1:2005 wersja polska',
#  '-EN 846-5:2012\n\t\t\t\t',
#  '-EN 846-6:2012\n\t\t\t\t',
#  '-EN 846-7:2012\n\t\t\t\t',
#  '-EN 846-8:2002\n\t\t\t\t',
#  '-EN 846-8:2002/A1:2006 wersja angielska',
#  '-EN 846-9:2016-06\n\t\t\t\t',
#  '-EN 846-10:2002\n\t\t\t\t',
#  '-EN 846-11:2002\n\t\t\t\t',
#  '-EN 846-13:2003\n\t\t\t\t',
#  '-EN 846-14:2012\n\t\t\t\t',
#  '-EN 858-1:2005\n\t\t\t\t',
#  '-EN 858-1:2005/A1:2007 wersja polska',
#  '-EN 858-2:2005\n\t\t\t\t',
#  '-EN 877:2004\n\t\t\t\t',
#  '-EN 877:2004/AC:2009 wersja polska',
#  '-EN 877:2004/A1:2007 wersja polska',
#  '-EN 912:2011\n\t\t\t\t',
#  '-EN 932-1:1999\n\t\t\t\t',
#  '-EN 932-2:2001\n\t\t\t\t',
#  '-EN 932-3:1999\n\t\t\t\t',
#  '-EN 932-3:1999/A1:2004 wersja polska',
#  '-EN 932-5:2012\n\t\t\t\t',
#  '-EN 932-5:2012/AC:2014-07 wersja angielska',
#  '-EN 932-6:2002\n\t\t\t\t',
#  '-EN 933-1:2012\n\t\t\t\t',
#  '-EN 933-2:1999\n\t\t\t\t',
#  '-EN 933-3:2012\n\t\t\t\t',
#  '-EN 933-4:2008\n\t\t\t\t',
#  '-EN 933-5:2000\n\t\t\t\t',
#  '-EN 933-5:2000/A1:2005 wersja polska',
#  '-EN 933-6:2014-07\n\t\t\t\t',
#  '-EN 933-7:2000\n\t\t\t\t',
#  '-EN 933-8+A1:2015-07\n\t\t\t\t',
#  '-EN 933-9+A1:2013-07\n\t\t\t\t',
#  '-EN 933-10:2009\n\t\t\t\t',
#  '-EN 933-11:2009\n\t\t\t\t',
#  '-EN 933-11:2009/AC:2010 wersja angielska',
#  '-EN 934-1:2009\n\t\t\t\t',
#  '-EN 934-2+A1:2012\n\t\t\t\t',
#  '-EN 934-3+A1:2012\n\t\t\t\t',
#  '-EN 934-4:2010\n\t\t\t\t',
#  '-EN 934-5:2009\n\t\t\t\t',
#  '-EN 934-6:2019-04\n\t\t\t\t',
#  '-EN 947:2000\n\t\t\t\t',
#  '-EN 948:2000\n\t\t\t\t',
#  '-EN 949:2000\n\t\t\t\t',
#  '-EN 950:2000\n\t\t\t\t',
#  '-EN 951:2000\n\t\t\t\t',
#  '-EN 952:2000\n\t\t\t\t',
#  '-EN 989:1999\n\t\t\t\t',
#  '-EN 990:2004\n\t\t\t\t',
#  '-EN 991:1999\n\t\t\t\t',
#  '-EN 992:1999\n\t\t\t\t',
#  '-EN 997:2018-11\n\t\t\t\t',
#  '-EN 998-1:2016-12\n\t\t\t\t',
#  '-EN 998-2:2016-12\n\t\t\t\t',
#  '-EN 1008:2004\n\t\t\t\t',
#  '-EN 1013+A1:2015-03\n\t\t\t\t',
#  '-EN 1015-1:2000\n\t\t\t\t',
#  '-EN 1015-1:2000/A1:2007 wersja angielska',
#  '-EN 1015-2:2000\n\t\t\t\t',
#  '-EN 1015-2:2000/A1:2007 wersja angielska',
#  '-EN 1015-3:2000\n\t\t\t\t',
#  '-EN 1015-3:2000/A2:2007 wersja angielska',
#  '-EN 1015-3:2000/A1:2005 wersja polska',
#  '-EN 1015-4:2000\n\t\t\t\t',
#  '-EN 1015-6:2000\n\t\t\t\t',
#  '-EN 1015-6:2000/A1:2007 wersja angielska',
#  '-EN 1015-7:2000\n\t\t\t\t',
#  '-EN 1015-9:2001\n\t\t\t\t',
#  '-EN 1015-9:2001/A1:2007 wersja angielska',
#  '-EN 1015-9:2001/A1:2007 wersja niemiecka',
#  '-EN 1015-10:2001\n\t\t\t\t',
#  '-EN 1015-10:2001/A1:2007 wersja angielska',
#  '-EN 1015-10:2001/A1:2007 wersja niemiecka',
#  '-EN 1015-11:2001\n\t\t\t\t',
#  '-EN 1015-11:2001/A1:2007 wersja angielska',
#  '-EN 1015-11:2001/A1:2007 wersja niemiecka',
#  '-EN 1015-12:2016-08\n\t\t\t\t',
#  '-EN 1015-17:2002\n\t\t\t\t',
#  '-EN 1015-17:2002/A1:2005 wersja polska',
#  '-EN 1015-18:2003\n\t\t\t\t',
#  '-EN 1015-19:2000\n\t\t\t\t',
#  '-EN 1015-19:2000/A1:2005 wersja polska',
#  '-EN 1015-21:2003\n\t\t\t\t',
#  '-EN 1024:2012\n\t\t\t\t',
#  '-EN 1024:2012\n\t\t\t\t',
#  '-EN 1026:2016-04\n\t\t\t\t',
#  '-EN 1027:2016-04\n\t\t\t\t',
#  '-EN 1036-1:2008\n\t\t\t\t',
#  '-EN 1036-1:2008\n\t\t\t\t',
#  '-EN 1036-2:2008\n\t\t\t\t',
#  '-EN 1036-2:2010\n\t\t\t\t',
#  '-EN 1051-1:2005\n\t\t\t\t',
#  '-EN 1051-2:2009\n\t\t\t\t',
#  '-EN 1052-1:2000\n\t\t\t\t',
#  '-EN 1052-2:2016-06\n\t\t\t\t',
#  '-EN 1052-2:2016-06/AC:2017-08 wersja angielska',
#  '-EN 1052-3:2004\n\t\t\t\t',
#  '-EN 1052-3:2004/A1:2009 wersja polska',
#  '-EN 1052-4:2002\n\t\t\t\t',
#  '-EN 1052-5:2005\n\t\t\t\t',
#  '-EN 1063:2002\n\t\t\t\t',
#  '-EN 1075:2015-03\n\t\t\t\t',
#  '-EN 1090-1+A1:2012\n\t\t\t\t',
#  '-EN 1090-2:2018-09\n\t\t\t\t',
#  '-EN 1090-2:2018-09\n\t\t\t\t',
#  '-EN 1090-3:2019-05\n\t\t\t\t',
#  '-EN 1090-4:2018-09\n\t\t\t\t',
#  '-EN 1090-5:2017-05\n\t\t\t\t',
#  '-EN 1096-1:2012\n\t\t\t\t',
#  '-EN 1096-1:2012\n\t\t\t\t',
#  '-EN 1096-2:2012\n\t\t\t\t',
#  '-EN 1096-3:2012\n\t\t\t\t',
#  '-EN 1096-4:2018-10\n\t\t\t\t',
#  '-EN 1096-5:2016-03\n\t\t\t\t',
#  '-EN 1096-5:2016-03\n\t\t\t\t',
#  '-EN 1097-1:2011\n\t\t\t\t',
#  '-EN 1097-2:2010\n\t\t\t\t',
#  '-EN 1097-3:2000\n\t\t\t\t',
#  '-EN 1097-4:2008\n\t\t\t\t',
#  '-EN 1097-5:2008\n\t\t\t\t',
#  '-EN 1097-6:2013-11\n\t\t\t\t',
#  '-EN 1097-7:2008\n\t\t\t\t',
#  '-EN 1097-8:2009\n\t\t\t\t',
#  '-EN 1097-9:2014-02\n\t\t\t\t',
#  '-EN 1097-10:2014-07\n\t\t\t\t',
#  '-EN 1097-11:2013-11\n\t\t\t\t',
#  '-EN 1107-1:2001\n\t\t\t\t',
#  '-EN 1107-2:2002\n\t\t\t\t',
#  '-EN 1108:2001\n\t\t\t\t',
#  '-EN 1109:2013-07\n\t\t\t\t',
#  '-EN 1110:2011\n\t\t\t\t',
#  '-EN 1111:2017-09\n\t\t\t\t',
#  '-EN 1112:2008\n\t\t\t\t',
#  '-EN 1113:2015-06\n\t\t\t\t',
#  '-EN 1121:2001\n\t\t\t\t',
#  '-EN 1123-1:2007\n\t\t\t\t',
#  '-EN 1123-2+A1:2007\n\t\t\t\t',
#  '-EN 1123-3:2005\n\t\t\t\t',
#  '-EN 1124-1:2007\n\t\t\t\t',
#  '-EN 1124-2:2014-07\n\t\t\t\t',
#  '-EN 1124-3:2008\n\t\t\t\t',
#  '-EN 1124-4:2014-02\n\t\t\t\t',
#  '-EN 1125:2009\n\t\t\t\t',
#  '-EN 1154:1999\n\t\t\t\t',
#  '-EN 1154:1999/AC:2010 wersja polska',
#  '-EN 1154:1999/A1:2004 wersja polska',
#  '-EN 1155:1999\n\t\t\t\t',
#  '-EN 1155:1999/AC:2006 wersja polska',
#  '-EN 1155:1999/A1:2004 wersja polska',
#  '-EN 1158:1999\n\t\t\t\t',
#  '-EN 1158:1999/AC:2006 wersja polska',
#  '-EN 1158:1999/A1:2004 wersja polska',
#  '-EN 1168+A3:2011\n\t\t\t\t',
#  '-EN 1169:2001\n\t\t\t\t',
#  '-EN 1170-1:1999\n\t\t\t\t',
#  '-EN 1170-2:1999\n\t\t\t\t',
#  '-EN 1170-3:1999\n\t\t\t\t',
#  '-EN 1170-4:1999\n\t\t\t\t',
#  '-EN 1170-5:1999\n\t\t\t\t',
#  '-EN 1170-6:1999\n\t\t\t\t',
#  '-EN 1170-7:1999\n\t\t\t\t',
#  '-EN 1170-8:2009\n\t\t\t\t',
#  '-EN 1191:2013-06\n\t\t\t\t',
#  '-EN 1192:2001\n\t\t\t\t',
#  '-EN 1195:1999\n\t\t\t\t',
#  '-EN 1213:2002\n\t\t\t\t',
#  '-EN 1253-1:2015-03\n\t\t\t\t',
#  '-EN 1253-2:2015-03\n\t\t\t\t',
#  '-EN 1253-3:2016-07\n\t\t\t\t',
#  '-EN 1253-4:2016-06\n\t\t\t\t',
#  '-EN 1253-5:2017-03\n\t\t\t\t',
#  '-EN 1264-1:2011\n\t\t\t\t',
#  '-EN 1264-2+A1:2013-05\n\t\t\t\t',
#  '-EN 1264-3:2009\n\t\t\t\t',
#  '-EN 1264-3:2009/Ap1:2016-09 wersja angielska',
#  '-EN 1264-4:2009\n\t\t\t\t',
#  '-EN 1264-4:2009/Ap1:2016-09 wersja angielska',
#  '-EN 1264-5:2008\n\t\t\t\t',
#  '-EN 1279-1:2018-08\n\t\t\t\t',
#  '-EN 1279-2:2018-08\n\t\t\t\t',
#  '-EN 1279-3:2018-08\n\t\t\t\t',
#  '-EN 1279-4:2018-08\n\t\t\t\t',
#  '-EN 1279-5:2018-08\n\t\t\t\t',
#  '-EN 1279-6:2018-08\n\t\t\t\t',
#  '-EN 1286:2004\n\t\t\t\t',
#  '-EN 1287:2017-09\n\t\t\t\t',
#  '-EN 1288-1:2002\n\t\t\t\t',
#  '-EN 1288-2:2002\n\t\t\t\t',
#  '-EN 1288-3:2002\n\t\t\t\t',
#  '-EN 1288-4:2002\n\t\t\t\t',
#  '-EN 1288-5:2002\n\t\t\t\t',
#  '-EN 1294:2002\n\t\t\t\t',
#  '-EN 1295-1:2019-05\n\t\t\t\t',
#  '-EN 1296:2002\n\t\t\t\t',
#  '-EN 1297:2006\n\t\t\t\t',
#  '-EN 1303:2015-07\n\t\t\t\t',
#  '-EN 1304:2013-10\n\t\t\t\t',
#  '-EN 1304:2013-10\n\t\t\t\t',
#  '-EN 1317-1:2010\n\t\t\t\t',
#  '-EN 1317-2:2010\n\t\t\t\t',
#  '-EN 1317-3:2010\n\t\t\t\t',
#  '-EN 1317-5+A2:2012\n\t\t\t\t',
#  '-EN 1317-5+A2:2012/AC:2014-02 wersja angielska',
#  '-EN 1337-1:2003\n\t\t\t\t',
#  '-EN 1337-2:2005\n\t\t\t\t',
#  '-EN 1337-3:2010\n\t\t\t\t',
#  '-EN 1337-4:2010\n\t\t\t\t',
#  '-EN 1337-5:2010\n\t\t\t\t',
#  '-EN 1337-6:2010\n\t\t\t\t',
#  '-EN 1337-7:2010\n\t\t\t\t',
#  '-EN 1337-8:2008\n\t\t\t\t',
#  '-EN 1337-9:2001\n\t\t\t\t',
#  '-EN 1337-10:2005\n\t\t\t\t',
#  '-EN 1337-11:2001\n\t\t\t\t',
#  '-EN 1338:2005\n\t\t\t\t',
#  '-EN 1338:2005/AC:2007 wersja polska',
#  '-EN 1339:2005\n\t\t\t\t',
#  '-EN 1339:2005/AC:2007 wersja polska',
#  '-EN 1340:2004\n\t\t\t\t',
#  '-EN 1340:2004/AC:2007 wersja polska',
#  '-EN 1341:2013-05\n\t\t\t\t',
#  '-EN 1342:2013-05\n\t\t\t\t',
#  '-EN 1342:2013-05\n\t\t\t\t',
#  '-EN 1343:2013-05\n\t\t\t\t',
#  '-EN 1344:2014-02\n\t\t\t\t',
#  '-EN 1344:2014-02/AC:2015-07 wersja angielska',
#  '-EN 1351:1999\n\t\t\t\t',
#  '-EN 1352:1999\n\t\t\t\t',
#  '-EN 1353:1999\n\t\t\t\t',
#  '-EN 1354:2006\n\t\t\t\t',
#  '-EN 1355:1999\n\t\t\t\t',
#  '-EN 1356:1999\n\t\t\t\t',
#  '-EN 1363-1:2012\n\t\t\t\t',
#  '-EN 1363-1:2012/Ap1:2015-12 wersja polska',
#  '-EN 1363-1:2012\n\t\t\t\t',
#  '-EN 1363-2:2001\n\t\t\t\t',
#  '-EN 1364-1:2015-08\n\t\t\t\t',
#  '-EN 1364-1:2015-08\n\t\t\t\t',
#  '-EN 1364-2:2018-02\n\t\t\t\t',
#  '-EN 1364-3:2014-03\n\t\t\t\t',
#  '-EN 1364-3:2014-03\n\t\t\t\t',
#  '-EN 1364-4:2014-04\n\t\t\t\t',
#  '-EN 1364-4:2014-04\n\t\t\t\t',
#  '-EN 1364-5:2017-08\n\t\t\t\t',
#  '-EN 1365-1:2013-04\n\t\t\t\t',
#  '-EN 1365-1:2013-04/AC:2013-06 wersja polska',
#  '-EN 1365-1:2013-04\n\t\t\t\t',
#  '-EN 1365-1:2013-04/AC:2013-06 wersja angielska',
#  '-EN 1365-2:2014-12\n\t\t\t\t',
#  '-EN 1365-2:2014-12\n\t\t\t\t',
#  '-EN 1365-3:2002\n\t\t\t\t',
#  '-EN 1365-4:2001\n\t\t\t\t',
#  '-EN 1365-5:2006\n\t\t\t\t',
#  '-EN 1365-6:2006\n\t\t\t\t',
#  '-EN 1366-1:2014-11\n\t\t\t\t',
#  '-EN 1366-1:2014-11\n\t\t\t\t',
#  '-EN 1366-2:2015-08\n\t\t\t\t',
#  '-EN 1366-2:2015-08\n\t\t\t\t',
#  '-EN 1366-3:2010\n\t\t\t\t',
#  '-EN 1366-4+A1:2011\n\t\t\t\t',
#  '-EN 1366-5:2011\n\t\t\t\t',
#  '-EN 1366-6:2006\n\t\t\t\t',
#  '-EN 1366-7:2006\n\t\t\t\t',
#  '-EN 1366-8:2006\n\t\t\t\t',
#  '-EN 1366-9:2009\n\t\t\t\t',
#  '-EN 1366-10+A1:2017-05\n\t\t\t\t',
#  '-EN 1366-10+A1:2017-05\n\t\t\t\t',
#  '-EN 1366-10+A1:2017-05/Ap1:2018-08 wersja angielska',
#  '-EN 1366-11:2018-06\n\t\t\t\t',
#  '-EN 1366-12:2014-11\n\t\t\t\t',
#  '-EN 1366-13:2019-05\n\t\t\t\t',
#  '-EN 1367-1:2007\n\t\t\t\t',
#  '-EN 1367-2:2010\n\t\t\t\t',
#  '-EN 1367-3:2002\n\t\t\t\t',
#  '-EN 1367-3:2002/AC:2004 wersja polska',
#  '-EN 1367-4:2010\n\t\t\t\t',
#  '-EN 1367-5:2011\n\t\t\t\t',
#  '-EN 1367-6:2008\n\t\t\t\t',
#  '-EN 1367-7:2014-07\n\t\t\t\t',
#  '-EN 1367-8:2014-07\n\t\t\t\t',
#  '-EN 1380:2009\n\t\t\t\t',
#  '-EN 1381:2016-03\n\t\t\t\t',
#  '-EN 1382:2016-03\n\t\t\t\t',
#  '-EN 1383:2016-03\n\t\t\t\t',
#  '-EN 1420:2016-03\n\t\t\t\t',
#  '-EN 1423:2012\n\t\t\t\t',
#  '-EN 1423:2012/AC:2013-05 wersja angielska',
#  '-EN 1424:2001\n\t\t\t\t',
#  '-EN 1424:2001/A1:2005 wersja polska',
#  '-EN 1433:2005\n\t\t\t\t',
#  '-EN 1433:2005/A1:2007 wersja polska',
#  '-EN 1436:2018-02\n\t\t\t\t',
#  '-EN 1443:2019-05\n\t\t\t\t',
#  '-EN 1444:2002\n\t\t\t\t',
#  '-EN 1457-1:2012\n\t\t\t\t',
#  '-EN 1457-1:2012\n\t\t\t\t',
#  '-EN 1457-1:2012/Ap1:2013-11 wersja angielska',
#  '-EN 1457-2:2012\n\t\t\t\t',
#  '-EN 1457-2:2012\n\t\t\t\t',
#  '-EN 1457-2:2012/Ap1:2013-11 wersja angielska',
#  '-EN 1462:2006\n\t\t\t\t',
#  '-EN 1463-1:2009\n\t\t\t\t',
#  '-EN 1463-2:2003\n\t\t\t\t',
#  '-EN 1467:2012\n\t\t\t\t',
#  '-EN 1468:2012\n\t\t\t\t',
#  '-EN 1469:2015-04\n\t\t\t\t',
#  '-EN 1487:2014-08\n\t\t\t\t',
#  '-EN 1488:2004\n\t\t\t\t',
#  '-EN 1489:2003\n\t\t\t\t',
#  '-EN 1490:2004\n\t\t\t\t',
#  '-EN 1491:2004\n\t\t\t\t',
#  '-EN 1504-1:2006\n\t\t\t\t',
#  '-EN 1504-2:2006\n\t\t\t\t',
#  '-EN 1504-3:2006\n\t\t\t\t',
#  '-EN 1504-4:2006\n\t\t\t\t',
#  '-EN 1504-5:2013-09\n\t\t\t\t',
#  '-EN 1504-5:2013-09\n\t\t\t\t',
#  '-EN 1504-6:2007\n\t\t\t\t',
#  '-EN 1504-7:2007\n\t\t\t\t',
#  '-EN 1504-8:2016-07\n\t\t\t\t',
#  '-EN 1504-8:2016-07\n\t\t\t\t',
#  '-EN 1504-9:2010\n\t\t\t\t',
#  '-EN 1504-10:2017-12\n\t\t\t\t',
#  '-EN 1505:2001\n\t\t\t\t',
#  '-EN 1506:2007\n\t\t\t\t',
#  '-EN 1507:2007\n\t\t\t\t',
#  '-EN 1508:2002\n\t\t\t\t',
#  '-EN 1520:2011\n\t\t\t\t',
#  '-EN 1521:1999\n\t\t\t\t',
#  '-EN 1522:2000\n\t\t\t\t',
#  '-EN 1523:2000\n\t\t\t\t',
#  '-EN 1527:2013-05\n\t\t\t\t',
#  '-EN 1529:2001\n\t\t\t\t',
#  '-EN 1530:2001\n\t\t\t\t',
#  '-EN 1536+A1:2015-08\n\t\t\t\t',
#  '-EN 1537:2013-11\n\t\t\t\t',
#  '-EN 1537:2013-11\n\t\t\t\t',
#  '-EN 1538+A1:2015-08\n\t\t\t\t',
#  '-EN 1538+A1:2015-08\n\t\t\t\t',
#  '-EN 1538+A1:2015-08/Ap1:2017-11 wersja angielska',
#  '-EN 1542:2000\n\t\t\t\t',
#  '-EN 1543:2000\n\t\t\t\t',
#  '-EN 1544:2007\n\t\t\t\t',
#  '-EN 1548:2010\n\t\t\t\t',
#  '-EN 1567:2004\n\t\t\t\t',
#  '-EN 1602:2013-07\n\t\t\t\t',
#  '-EN 1603:2013-07\n\t\t\t\t',
#  '-EN 1604:2013-07\n\t\t\t\t',
#  '-EN 1605:2013-07\n\t\t\t\t',
#  '-EN 1606:2013-07\n\t\t\t\t',
#  '-EN 1607:2013-07\n\t\t\t\t',
#  '-EN 1608:2013-07\n\t\t\t\t',
#  '-EN 1610:2015-10\n\t\t\t\t',
#  '-EN 1610:2015-10\n\t\t\t\t',
#  '-EN 1627:2012\n\t\t\t\t',
#  '-EN 1627:2012/Ap1:2015-03 wersja polska',
#  '-EN 1628+A1:2016-02\n\t\t\t\t',
#  '-EN 1629+A1:2016-02\n\t\t\t\t',
#  '-EN 1630+A1:2016-02\n\t\t\t\t',
#  '-EN 1634-1+A1:2018-03\n\t\t\t\t',
#  '-EN 1634-2:2009\n\t\t\t\t',
#  '-EN 1634-3:2006\n\t\t\t\t',
#  '-EN 1634-3:2006/AC:2006 wersja polska',
#  '-EN 1670:2008\n\t\t\t\t',
#  '-EN 1717:2003\n\t\t\t\t',
#  '-EN 1737:2000\n\t\t\t\t',
#  '-EN 1738:2000\n\t\t\t\t',
#  '-EN 1739:2007\n\t\t\t\t',
#  '-EN 1740:2000\n\t\t\t\t',
#  '-EN 1741:2000\n\t\t\t\t',
#  '-EN 1742:2000\n\t\t\t\t',
#  '-EN 1744-1+A1:2013-05\n\t\t\t\t',
#  '-EN 1744-3:2004\n\t\t\t\t',
#  '-EN 1744-3:2004/Ap1:2014-01 wersja polska',
#  '-EN 1744-4:2008\n\t\t\t\t',
#  '-EN 1744-5:2008\n\t\t\t\t',
#  '-EN 1744-6:2008\n\t\t\t\t',
#  '-EN 1744-7:2012\n\t\t\t\t',
#  '-EN 1744-8:2013-02\n\t\t\t\t',
#  '-EN 1745:2012\n\t\t\t\t',
#  '-EN 1748-1-1:2005\n\t\t\t\t',
#  '-EN 1748-1-2:2008\n\t\t\t\t',
#  '-EN 1748-2-1:2005\n\t\t\t\t',
#  '-EN 1748-2-2:2010\n\t\t\t\t',
#  '-EN 1751:2014-03\n\t\t\t\t',
#  '-EN 1766:2017-03\n\t\t\t\t',
#  '-EN 1766:2017-03\n\t\t\t\t',
#  '-EN 1767:2008\n\t\t\t\t',
#  '-EN 1770:2000\n\t\t\t\t',
#  '-EN 1771:2005\n\t\t\t\t',
#  '-EN 1771:2005/AC:2005 wersja angielska',
#  '-EN 1790:2014-02\n\t\t\t\t',
#  '-EN 1793-1:2017-05\n\t\t\t\t',
#  '-EN 1793-2:2018-08\n\t\t\t\t',
#  '-EN 1793-3:2001\n\t\t\t\t',
#  '-EN 1793-4:2015-05\n\t\t\t\t',
#  '-EN 1793-5:2016-05\n\t\t\t\t',
#  '-EN 1793-5:2016-05/AC:2018-08 wersja angielska',
#  '-EN 1793-6:2018-08\n\t\t\t\t',
#  '-EN 1794-1+AC:2019-02\n\t\t\t\t',
#  '-EN 1794-2:2011\n\t\t\t\t',
#  '-EN 1794-3:2016-08\n\t\t\t\t',
#  '-EN 1799:2000\n\t\t\t\t',
#  '-EN 1806:2008\n\t\t\t\t',
#  '-EN 1822-1:2019-05\n\t\t\t\t',
#  '-EN 1824:2011\n\t\t\t\t',
#  '-EN 1825-1:2007\n\t\t\t\t',
#  '-EN 1825-2:2005\n\t\t\t\t',
#  '-EN 1844:2013-07\n\t\t\t\t',
#  '-EN 1847:2010\n\t\t\t\t',
#  '-EN 1848-1:2002\n\t\t\t\t',
#  '-EN 1848-2:2003\n\t\t\t\t',
#  '-EN 1849-1:2002\n\t\t\t\t',
#  '-EN 1849-2:2019-08\n\t\t\t\t',
#  '-EN 1850-1:2002\n\t\t\t\t',
#  '-EN 1850-2:2004\n\t\t\t\t',
#  '-EN 1856-1:2009\n\t\t\t\t',
#  '-EN 1856-1:2009\n\t\t\t\t',
#  '-EN 1856-2:2009\n\t\t\t\t',
#  '-EN 1856-2:2009\n\t\t\t\t',
#  '-EN 1857:2010\n\t\t\t\t',
#  '-EN 1857:2010\n\t\t\t\t',
#  '-EN 1858+A1:2011\n\t\t\t\t',
#  '-EN 1859+A1:2013-09\n\t\t\t\t',
#  '-EN 1859+A1:2013-09\n\t\t\t\t',
#  '-EN 1863-1:2012\n\t\t\t\t',
#  '-EN 1863-1:2012\n\t\t\t\t',
#  '-EN 1863-2:2008\n\t\t\t\t',
#  '-EN 1871:2003\n\t\t\t\t',
#  '-EN 1871:2003/Ap1:2013-12 wersja polska',
#  '-EN 1873+A1:2016-03\n\t\t\t\t',
#  '-EN 1877-1:2002\n\t\t\t\t',
#  '-EN 1877-2:2002\n\t\t\t\t',
#  '-EN 1881:2007\n\t\t\t\t',
#  '-EN 1886:2008\n\t\t\t\t',
#  '-EN 1906:2012\n\t\t\t\t',
#  '-EN 1912:2012\n\t\t\t\t',
#  '-EN 1912:2012/AC:2013-09 wersja angielska',
#  '-EN 1916:2005\n\t\t\t\t',
#  '-EN 1916:2005/AC:2009 wersja polska',
#  '-EN 1917:2004\n\t\t\t\t',
#  '-EN 1917:2004/AC:2009 wersja polska',
#  '-EN 1925:2001\n\t\t\t\t',
#  '-EN 1926:2007\n\t\t\t\t',
#  '-EN 1928:2002\n\t\t\t\t',
#  '-EN 1931:2002\n\t\t\t\t',
#  '-EN 1932:2013-09\n\t\t\t\t',
#  '-EN 1933:2005\n\t\t\t\t',
#  '-EN 1934:1999\n\t\t\t\t',
#  '-EN 1935:2003\n\t\t\t\t',
#  '-EN 1935:2003/AC:2005 wersja polska',
#  '-EN 1936:2010\n\t\t\t\t',
#  '-EN 1946-1:2000\n\t\t\t\t',
#  '-EN 1946-2:2000\n\t\t\t\t',
#  '-EN 1946-3:2000\n\t\t\t\t',
#  '-EN 1946-4:2002\n\t\t\t\t',
#  '-EN 1946-5:2002\n\t\t\t\t',
#  '-EN 1990:2004\n\t\t\t\t',
#  '-EN 1990:2004/NA:2010 wersja polska',
#  '-EN 1990:2004/AC:2010 wersja polska',
#  '-EN 1990:2004/Ap2:2010 wersja polska',
#  '-EN 1990:2004/A1:2008 wersja polska',
#  '-EN 1990:2004/Ap1:2004 wersja polska',
#  '-EN 1991-1-1:2004\n\t\t\t\t',
#  '-EN 1991-1-1:2004/Ap2:2011 wersja polska',
#  '-EN 1991-1-1:2004/NA:2010 wersja polska',
#  '-EN 1991-1-1:2004/Ap1:2010 wersja polska',
#  '-EN 1991-1-1:2004/AC:2009 wersja polska',
#  '-EN 1991-1-2:2006\n\t\t\t\t',
#  '-EN 1991-1-2:2006/Ap2:2014-12 wersja polska',
#  '-EN 1991-1-2:2006/AC:2013-07 wersja polska',
#  '-EN 1991-1-2:2006/NA:2010 wersja polska',
#  '-EN 1991-1-2:2006/Ap1:2010 wersja polska',
#  '-EN 1991-1-3:2005\n\t\t\t\t',
#  '-EN 1991-1-3:2005/A1:2015-10 wersja angielska',
#  '-EN 1991-1-3:2005/NA:2010 wersja polska',
#  '-EN 1991-1-3:2005/Ap1:2010 wersja polska',
#  '-EN 1991-1-3:2005/AC:2009 wersja polska',
#  '-EN 1991-1-4:2008\n\t\t\t\t',
#  '-EN 1991-1-4:2008/A1:2010 wersja polska',
#  '-EN 1991-1-4:2008/Ap3:2011 wersja polska',
#  '-EN 1991-1-4:2008/A1:2010 wersja niemiecka',
#  '-EN 1991-1-4:2008/A1:2010 wersja angielska',
#  '-EN 1991-1-4:2008/NA:2010 wersja polska',
#  '-EN 1991-1-4:2008/Ap2:2010 wersja polska',
#  '-EN 1991-1-4:2008/Ap1:2010 wersja polska',
#  '-EN 1991-1-4:2008/AC:2009 wersja polska',
#  '-EN 1991-1-5:2005\n\t\t\t\t',
#  '-EN 1991-1-5:2005/NA:2010 wersja polska',
#  '-EN 1991-1-5:2005/Ap1:2010 wersja polska',
#  '-EN 1991-1-5:2005/AC:2009 wersja polska',
#  '-EN 1991-1-6:2007\n\t\t\t\t',
#  '-EN 1991-1-6:2007/AC:2013-07 wersja polska',
#  '-EN 1991-1-6:2007/NA:2010 wersja polska',
#  '-EN 1991-1-6:2007/Ap1:2010 wersja polska',
#  '-EN 1991-1-7:2008\n\t\t\t\t',
#  '-EN 1991-1-7:2008/NA:2015-02 wersja polska',
#  '-EN 1991-1-7:2008/Ap2:2014-12 wersja polska',
#  '-EN 1991-1-7:2008/A1:2014-07 wersja angielska',
#  '-EN 1991-1-7:2008/NA:2010 wersja polska',
#  '-EN 1991-1-7:2008/Ap1:2010 wersja polska',
#  '-EN 1991-1-7:2008/AC:2010 wersja polska',
#  '-EN 1991-2:2007\n\t\t\t\t',
#  '-EN 1991-2:2007/AC:2010 wersja polska',
#  '-EN 1991-2:2007/Ap1:2010 wersja polska',
#  '-EN 1991-3:2009\n\t\t\t\t',
#  '-EN 1991-3:2009/AC:2014-11 wersja polska',
#  '-EN 1991-3:2009/NA:2010 wersja polska',
#  '-EN 1991-3:2009/Ap1:2010 wersja polska',
#  '-EN 1991-4:2008\n\t\t\t\t',
#  '-EN 1991-4:2008/AC:2013-04 wersja polska',
#  '-EN 1991-4:2008/Ap3:2013-04 wersja polska',
#  '-EN 1991-4:2008/NA:2010 wersja polska',
#  '-EN 1991-4:2008/Ap2:2010 wersja polska',
#  '-EN 1991-4:2008/Ap1:2010 wersja polska',
#  '-EN 1992-1-1:2008\n\t\t\t\t',
#  '-EN 1992-1-1:2008/NA:2018-11 wersja polska',
#  '-EN 1992-1-1:2008/Ap3:2018-08 wersja polska',
#  '-EN 1992-1-1:2008/NA:2016-11 wersja polska',
#  '-EN 1992-1-1:2008/Ap2:2016-10 wersja polska',
#  '-EN 1992-1-1:2008/A1:2015-03 wersja angielska',
#  '-EN 1992-1-1:2008/AC:2011 wersja polska',
#  '-EN 1992-1-1:2008/NA:2010 wersja polska',
#  '-EN 1992-1-1:2008/Ap1:2010 wersja polska',
#  '-EN 1992-1-2:2008\n\t\t\t\t',
#  '-EN 1992-1-2:2008/A1:2019-07 wersja angielska',
#  '-EN 1992-1-2:2008/Ap2:2016-09 wersja polska',
#  '-EN 1992-1-2:2008/NA:2010 wersja polska',
#  '-EN 1992-1-2:2008/Ap1:2010 wersja polska',
#  '-EN 1992-1-2:2008/AC:2008 wersja polska',
#  '-EN 1992-2:2010\n\t\t\t\t',
#  '-EN 1992-2:2010/NA:2016-11 wersja polska',
#  '-EN 1992-2:2010/Ap2:2016-10 wersja polska',
#  '-EN 1992-2:2010/Ap1:2010 wersja polska',
#  '-EN 1992-3:2008\n\t\t\t\t',
#  '-EN 1992-3:2008/NA:2010 wersja polska',
#  '-EN 1992-3:2008/Ap1:2010 wersja polska',
#  '-EN 1992-4:2018-11\n\t\t\t\t',
#  '-EN 1993-1-1:2006\n\t\t\t\t',
#  '-EN 1993-1-1:2006/A1:2014-07 wersja polska',
#  '-EN 1993-1-1:2006/A1:2014-07 wersja angielska',
#  '-EN 1993-1-1:2006/NA:2010 wersja polska',
#  '-EN 1993-1-1:2006/Ap1:2010 wersja polska',
#  '-EN 1993-1-1:2006/AC:2009 wersja polska',
#  '-EN 1993-1-2:2007\n\t\t\t\t',
#  '-EN 1993-1-2:2007/NA:2010 wersja polska',
#  '-EN 1993-1-2:2007/Ap1:2009 wersja polska',
#  '-EN 1993-1-2:2007/AC:2009 wersja polska',
#  '-EN 1993-1-3:2008\n\t\t\t\t',
#  '-EN 1993-1-3:2008/NA:2010 wersja polska',
#  '-EN 1993-1-3:2008/Ap1:2010 wersja polska',
#  '-EN 1993-1-3:2008/AC:2009 wersja polska',
#  '-EN 1993-1-4:2007\n\t\t\t\t',
#  '-EN 1993-1-4:2007/A1:2015-08 wersja angielska',
#  '-EN 1993-1-4:2007/NA:2010 wersja polska',
#  '-EN 1993-1-4:2007/Ap1:2010 wersja polska',
#  '-EN 1993-1-5:2008\n\t\t\t\t',
#  '-EN 1993-1-5:2008/A1:2017-07 wersja angielska',
#  '-EN 1993-1-5:2008/NA:2010 wersja polska',
#  '-EN 1993-1-5:2008/Ap1:2010 wersja polska',
#  '-EN 1993-1-5:2008/AC:2009 wersja polska',
#  '-EN 1993-1-6:2009\n\t\t\t\t',
#  '-EN 1993-1-6:2009/A1:2017-07 wersja angielska',
#  '-EN 1993-1-6:2009/NA:2010 wersja polska',
#  '-EN 1993-1-6:2009/Ap1:2010 wersja polska',
#  '-EN 1993-1-7:2008\n\t\t\t\t',
#  '-EN 1993-1-7:2008/NA:2010 wersja polska',
#  '-EN 1993-1-7:2008/Ap1:2010 wersja polska',
#  '-EN 1993-1-7:2008/AC:2009 wersja polska',
#  '-EN 1993-1-8:2006\n\t\t\t\t',
#  '-EN 1993-1-8:2006/NA:2011 wersja polska',
#  '-EN 1993-1-8:2006/Ap2:2011 wersja polska',
#  '-EN 1993-1-8:2006/NA:2010 wersja polska',
#  '-EN 1993-1-8:2006/Ap1:2010 wersja polska',
#  '-EN 1993-1-8:2006/AC:2009 wersja polska',
#  '-EN 1993-1-9:2007\n\t\t\t\t',
#  '-EN 1993-1-9:2007/NA:2010 wersja polska',
#  '-EN 1993-1-9:2007/Ap1:2010 wersja polska',
#  '-EN 1993-1-9:2007/AC:2009 wersja polska',
#  '-EN 1993-1-10:2007\n\t\t\t\t',
#  '-EN 1993-1-10:2007/NA:2010 wersja polska',
#  '-EN 1993-1-10:2007/Ap1:2010 wersja polska',
#  '-EN 1993-1-10:2007/AC:2009 wersja polska',
#  '-EN 1993-1-11:2008\n\t\t\t\t',
#  '-EN 1993-1-11:2008/NA:2010 wersja polska',
#  '-EN 1993-1-11:2008/Ap1:2010 wersja polska',
#  '-EN 1993-1-11:2008/AC:2009 wersja polska',
#  '-EN 1993-1-12:2008\n\t\t\t\t',
#  '-EN 1993-1-12:2008/NA:2010 wersja polska',
#  '-EN 1993-1-12:2008/Ap1:2010 wersja polska',
#  '-EN 1993-1-12:2008/AC:2009 wersja polska',
#  '-EN 1993-2:2010\n\t\t\t\t',
#  '-EN 1993-2:2010/Ap1:2010 wersja polska',
#  '-EN 1993-3-1:2008\n\t\t\t\t',
#  '-EN 1993-3-1:2008/NA:2010 wersja polska',
#  '-EN 1993-3-1:2008/Ap2:2010 wersja polska',
#  '-EN 1993-3-1:2008/AC:2009 wersja polska',
#  '-EN 1993-3-1:2008/Ap1:2009 wersja polska',
#  '-EN 1993-3-2:2008\n\t\t\t\t',
#  '-EN 1993-3-2:2008/NA:2010 wersja polska',
#  '-EN 1993-3-2:2008/Ap1:2010 wersja polska',
#  '-EN 1993-4-1:2009\n\t\t\t\t',
#  '-EN 1993-4-1:2009/A1:2017-08 wersja angielska',
#  '-EN 1993-4-1:2009/NA:2010 wersja polska',
#  '-EN 1993-4-1:2009/Ap1:2010 wersja polska',
#  '-EN 1993-4-2:2009\n\t\t\t\t',
#  '-EN 1993-4-2:2009/A1:2017-08 wersja angielska',
#  '-EN 1993-4-2:2009/NA:2010 wersja polska',
#  '-EN 1993-4-2:2009/Ap1:2010 wersja polska',
#  '-EN 1993-5:2009\n\t\t\t\t',
#  '-EN 1993-5:2009/NA:2010 wersja polska',
#  '-EN 1993-6:2009\n\t\t\t\t',
#  '-EN 1993-6:2009/NA:2010 wersja polska',
#  '-EN 1993-6:2009/Ap1:2010 wersja polska',
#  '-EN 1993-6:2009/AC:2009 wersja polska',
#  '-EN 1994-1-1:2008\n\t\t\t\t',
#  '-EN 1994-1-1:2008/NA:2010 wersja polska',
#  '-EN 1994-1-1:2008/Ap1:2010 wersja polska',
#  '-EN 1994-1-1:2008/AC:2009 wersja polska',
#  '-EN 1994-1-2:2008\n\t\t\t\t',
#  '-EN 1994-1-2:2008/A1:2014-06 wersja angielska',
#  '-EN 1994-1-2:2008/NA:2010 wersja polska',
#  '-EN 1994-2:2010\n\t\t\t\t',
#  '-EN 1994-2:2010/Ap1:2010 wersja polska',
#  '-EN 1995-1-1:2010\n\t\t\t\t',
#  '-EN 1995-1-1:2010/A2:2014-07 wersja angielska',
#  '-EN 1995-1-1:2010/NA:2010 wersja polska',
#  '-EN 1995-1-2:2008\n\t\t\t\t',
#  '-EN 1995-1-2:2008/NA:2010 wersja polska',
#  '-EN 1995-1-2:2008/AC:2009 wersja polska',
#  '-EN 1995-2:2007\n\t\t\t\t',
#  '-EN 1995-2:2007/Ap1:2010 wersja polska',
#  '-EN 1996-1-1+A1:2013-05\n\t\t\t\t',
#  '-EN 1996-1-1+A1:2013-05/Ap3:2016-04 wersja polska',
#  '-EN 1996-1-1+A1:2013-05/Ap2:2014-09 wersja polska',
#  '-EN 1996-1-1+A1:2013-05\n\t\t\t\t',
#  '-EN 1996-1-1+A1:2013-05/NA:2014-10 wersja angielska',
#  '-EN 1996-1-1+A1:2013-05/Ap2:2014-09 wersja angielska',
#  '-EN 1996-1-1+A1:2013-05/NA:2014-03 wersja polska',
#  '-EN 1996-1-1+A1:2013-05/Ap1:2013-11 wersja angielska',
#  '-EN 1996-1-2:2010\n\t\t\t\t',
#  '-EN 1996-1-2:2010/AC:2011 wersja polska',
#  '-EN 1996-1-2:2010/NA:2010 wersja polska',
#  '-EN 1996-2:2010\n\t\t\t\t',
#  '-EN 1996-2:2010/NA:2010 wersja polska',
#  '-EN 1996-2:2010/Ap1:2010 wersja polska',
#  '-EN 1996-3:2010\n\t\t\t\t',
#  '-EN 1996-3:2010/NA:2016-06 wersja polska',
#  '-EN 1996-3:2010/Ap1:2016-05 wersja polska',
#  '-EN 1996-3:2010/NA:2010 wersja polska',
#  '-EN 1997-1:2008\n\t\t\t\t',
#  '-EN 1997-1:2008/A1:2014-05 wersja polska',
#  '-EN 1997-1:2008/A1:2014-05 wersja angielska',
#  '-EN 1997-1:2008/NA:2011 wersja polska',
#  '-EN 1997-1:2008/Ap2:2010 wersja polska',
#  '-EN 1997-1:2008/Ap1:2010 wersja polska',
#  '-EN 1997-1:2008/AC:2009 wersja polska',
#  '-EN 1997-2:2009\n\t\t\t\t',
#  '-EN 1997-2:2009/AC:2010 wersja polska',
#  '-EN 1997-2:2009/Ap1:2010 wersja polska',
#  '-EN 1998-1:2005\n\t\t\t\t',
#  '-EN 1998-1:2005\n\t\t\t\t',
#  '-EN 1998-1:2005/A1:2014-01 wersja angielska',
#  '-EN 1998-1:2005/AC:2009 wersja angielska',
#  '-EN 1998-2:2006\n\t\t\t\t',
#  '-EN 1998-2:2006\n\t\t\t\t',
#  '-EN 1998-2:2006/A2:2012 wersja angielska',
#  '-EN 1998-2:2006/AC:2010 wersja angielska',
#  '-EN 1998-2:2006/A1:2009 wersja angielska',
#  '-EN 1998-3:2005\n\t\t\t\t',
#  '-EN 1998-3:2005/AC:2014-09 wersja angielska',
#  '-EN 1998-4:2006\n\t\t\t\t',
#  '-EN 1998-4:2006\n\t\t\t\t',
#  '-EN 1998-5:2005\n\t\t\t\t',
#  '-EN 1998-5:2005\n\t\t\t\t',
#  '-EN 1998-6:2005\n\t\t\t\t',
#  '-EN 1998-6:2005\n\t\t\t\t',
#  '-EN 1999-1-1:2011\n\t\t\t\t',
#  '-EN 1999-1-1:2011/A2:2014-05 wersja polska',
#  '-EN 1999-1-1:2011/Ap1:2014-12 wersja polska',
#  '-EN 1999-1-1:2011/A2:2014-05 wersja angielska',
#  '-EN 1999-1-2:2007\n\t\t\t\t',
#  '-EN 1999-1-2:2007/AC:2009 wersja polska',
#  '-EN 1999-1-2:2007\n\t\t\t\t',
#  '-EN 1999-1-2:2007/AC:2009 wersja angielska',
#  '-EN 1999-1-3:2011\n\t\t\t\t',
#  '-EN 1999-1-3:2011/A1:2012 wersja polska',
#  '-EN 1999-1-4:2012\n\t\t\t\t',
#  '-EN 1999-1-5:2012\n\t\t\t\t',
#  '-EN 10242:1999\n\t\t\t\t',
#  '-EN 10242:1999/A2:2005 wersja polska',
#  '-EN 10242:1999/A1:2002 wersja polska',
#  '-EN 12039:2016-07\n\t\t\t\t',
#  '-EN 12039:2016-07/AC:2017-05 wersja angielska',
#  '-EN 12045:2005\n\t\t\t\t',
#  '-EN 12046-1:2005\n\t\t\t\t',
#  '-EN 12046-2:2001\n\t\t\t\t',
#  '-EN 12050-1:2015-05\n\t\t\t\t',
#  '-EN 12050-2:2015-04\n\t\t\t\t',
#  '-EN 12050-3:2015-05\n\t\t\t\t',
#  '-EN 12050-4:2015-05\n\t\t\t\t',
#  '-EN 12051:2002\n\t\t\t\t',
#  '-EN 12056-1:2002\n\t\t\t\t',
#  '-EN 12056-2:2002\n\t\t\t\t',
#  '-EN 12056-3:2002\n\t\t\t\t',
#  '-EN 12056-4:2002\n\t\t\t\t',
#  '-EN 12056-5:2002\n\t\t\t\t',
#  '-EN 12057:2015-04\n\t\t\t\t',
#  '-EN 12058:2015-04\n\t\t\t\t',
#  '-EN 12059+A1:2012\n\t\t\t\t',
#  '-EN 12059+A1:2012\n\t\t\t\t',
#  '-EN 12063:2001\n\t\t\t\t',
#  '-EN 12085:2013-07\n\t\t\t\t',
#  '-EN 12086:2013-07\n\t\t\t\t',
#  '-EN 12089:2013-07\n\t\t\t\t',
#  '-EN 12090:2013-07\n\t\t\t\t',
#  '-EN 12091:2013-07\n\t\t\t\t',
#  '-EN 12097:2007\n\t\t\t\t',
#  '-EN 12101-1:2007\n\t\t\t\t',
#  '-EN 12101-2:2017-05\n\t\t\t\t',
#  ...]

# %%
for s in lista:
    s = "PN"+s
print(lista)
# Out:
# ['-EN 31+A1:2014-07\n\t\t\t\t', '-EN 33:2019-06\n\t\t\t\t', '-EN 35:2014-07\n\t\t\t\t', '-EN 40-1:2002\n\t\t\t\t', '-EN 40-1:2002\n\t\t\t\t', '-EN 40-2:2005\n\t\t\t\t', '-EN 40-2:2005/Ap1:2006 wersja polska', '-EN 40-3-1:2013-06\n\t\t\t\t', '-EN 40-3-1:2013-06\n\t\t\t\t', '-EN 40-3-1:2013-06/Ap1:2014-08 wersja angielska', '-EN 40-3-2:2013-06\n\t\t\t\t', '-EN 40-3-2:2013-06\n\t\t\t\t', '-EN 40-3-3:2013-06\n\t\t\t\t', '-EN 40-3-3:2013-06\n\t\t\t\t', '-EN 40-4:2008\n\t\t\t\t', '-EN 40-5:2004\n\t\t\t\t', '-EN 40-6:2004\n\t\t\t\t', '-EN 40-7:2004\n\t\t\t\t', '-EN 80:2002\n\t\t\t\t', '-EN 107:2002\n\t\t\t\t', '-EN 124-1:2015-07\n\t\t\t\t', '-EN 124-1:2015-07\n\t\t\t\t', '-EN 124-1:2015-07/Ap1:2016-07 wersja angielska', '-EN 124-2:2015-07\n\t\t\t\t', '-EN 124-2:2015-07\n\t\t\t\t', '-EN 124-2:2015-07/Ap1:2017-07 wersja angielska', '-EN 124-3:2015-07\n\t\t\t\t', '-EN 124-3:2015-07\n\t\t\t\t', '-EN 124-3:2015-07/Ap1:2017-08 wersja angielska', '-EN 124-4:2015-07\n\t\t\t\t', '-EN 124-4:2015-07\n\t\t\t\t', '-EN 124-4:2015-07/Ap1:2017-08 wersja angielska', '-EN 124-5:2015-07\n\t\t\t\t', '-EN 124-5:2015-07\n\t\t\t\t', '-EN 124-5:2015-07/Ap1:2017-08 wersja angielska', '-EN 124-6:2015-07\n\t\t\t\t', '-EN 124-6:2015-07\n\t\t\t\t', '-EN 124-6:2015-07/Ap1:2017-08 wersja angielska', '-EN 130:1998\n\t\t\t\t', '-EN 179:2009\n\t\t\t\t', '-EN 196-1:2016-07\n\t\t\t\t', '-EN 196-1:2016-07\n\t\t\t\t', '-EN 196-2:2013-11\n\t\t\t\t', '-EN 196-2:2013-11\n\t\t\t\t', '-EN 196-3:2016-12\n\t\t\t\t', '-EN 196-3:2016-12\n\t\t\t\t', '-EN 196-5:2011\n\t\t\t\t', '-EN 196-5:2011\n\t\t\t\t', '-EN 196-6:2019-01\n\t\t\t\t', '-EN 196-7:2009\n\t\t\t\t', '-EN 196-8:2010\n\t\t\t\t', '-EN 196-9:2010\n\t\t\t\t', '-EN 196-10:2016-07\n\t\t\t\t', '-EN 196-10:2016-07\n\t\t\t\t', '-EN 196-11:2019-01\n\t\t\t\t', '-EN 197-1:2012\n\t\t\t\t', '-EN 197-1:2012\n\t\t\t\t', '-EN 197-1:2012\n\t\t\t\t', '-EN 197-2:2014-05\n\t\t\t\t', '-EN 197-2:2014-05\n\t\t\t\t', '-EN 198:2008\n\t\t\t\t', '-EN 198:2008\n\t\t\t\t', '-EN 200:2008\n\t\t\t\t', '-EN 200:2008\n\t\t\t\t', '-EN 206+A1:2016-12\n\t\t\t\t', '-EN 206+A1:2016-12\n\t\t\t\t', '-EN 215:2005\n\t\t\t\t', '-EN 215:2005/A1:2006 wersja angielska', '-EN 232:2013-04\n\t\t\t\t', '-EN 246:2005\n\t\t\t\t', '-EN 248:2005\n\t\t\t\t', '-EN 249:2010\n\t\t\t\t', '-EN 251:2013-04\n\t\t\t\t', '-EN 253+A2:2015-12\n\t\t\t\t', '-EN 253+A2:2015-12\n\t\t\t\t', '-EN 263:2008\n\t\t\t\t', '-EN 274-1:2004\n\t\t\t\t', '-EN 274-1:2004/Ap1:2012 wersja polska', '-EN 274-2:2004\n\t\t\t\t', '-EN 274-3:2004\n\t\t\t\t', '-EN 295-1:2013-06\n\t\t\t\t', '-EN 295-1:2013-06/Ap1:2013-07 wersja angielska', '-EN 295-2:2013-07\n\t\t\t\t', '-EN 295-3:2012\n\t\t\t\t', '-EN 295-4:2013-07\n\t\t\t\t', '-EN 295-5:2013-07\n\t\t\t\t', '-EN 295-6:2013-07\n\t\t\t\t', '-EN 295-7:2013-07\n\t\t\t\t', '-EN 303-1:2017-10\n\t\t\t\t', '-EN 303-2:2017-09\n\t\t\t\t', '-EN 303-3:2002\n\t\t\t\t', '-EN 303-3:2002/AC:2007 wersja polska', '-EN 303-3:2002/A2:2005 wersja polska', '-EN 303-4:2002\n\t\t\t\t', '-EN 303-5:2012\n\t\t\t\t', '-EN 303-5:2012\n\t\t\t\t', '-EN 303-5:2012\n\t\t\t\t', '-EN 303-6:2002\n\t\t\t\t', '-EN 303-7:2008\n\t\t\t\t', '-EN 304:2017-11\n\t\t\t\t', '-EN 336:2013-12\n\t\t\t\t', '-EN 338:2016-06\n\t\t\t\t', '-EN 356:2000\n\t\t\t\t', '-EN 380:1998\n\t\t\t\t', '-EN 383:2007\n\t\t\t\t', '-EN 384+A1:2018-12\n\t\t\t\t', '-EN 408+A1:2012\n\t\t\t\t', '-EN 409:2009\n\t\t\t\t', '-EN 410:2011\n\t\t\t\t', '-EN 410:2011\n\t\t\t\t', '-EN 410:2011/Ap1:2013-07 wersja angielska', '-EN 413-1:2011\n\t\t\t\t', '-EN 413-1:2011\n\t\t\t\t', '-EN 413-2:2016-11\n\t\t\t\t', '-EN 442-1:2015-02\n\t\t\t\t', '-EN 442-1:2015-02/Ap1:2018-05 wersja polska', '-EN 442-1:2015-02\n\t\t\t\t', '-EN 442-2:2015-02\n\t\t\t\t', '-EN 442-2:2015-02\n\t\t\t\t', '-EN 445:2009\n\t\t\t\t', '-EN 446:2009\n\t\t\t\t', '-EN 447:2009\n\t\t\t\t', '-EN 448:2015-12\n\t\t\t\t', '-EN 448:2015-12\n\t\t\t\t', '-EN 450-1:2012\n\t\t\t\t', '-EN 450-1:2012\n\t\t\t\t', '-EN 450-2:2006\n\t\t\t\t', '-EN 451-1:2017-06\n\t\t\t\t', '-EN 451-2:2017-06\n ...

# %%
import re
soup.find_all(string=re.compile("Zastępuje"))
# Out:
# ['\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  'Zastępuje',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  'Zastępuje',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  '\n\t\t\t\tZastępuje\n\t\t\t',
#  ...]

# %%
with open("test.html") as test:
    test_soup = bs4.BeautifulSoup(test, "html.parser")

# %%
divs = test_soup.find_all("div", class_="p4s-search-results-values")

# %%
divs
# Out:
# [<div class="p4s-search-results-values">
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  				Numer normy
#  			</span>
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+1109%3A2013-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  <span class="highlighted-search-term">PN</span>-EN 1109:2013-07
#  				<span style="margin-left: 10px;">
#  					wersja angielska
#  				</span>
#  </a>
#  </p>
#  <div class="p4s-clear"></div>
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  				Tytuł normy
#  			</span>
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+1109%3A2013-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  				Elastyczne wyroby wodochronne -- Wyroby asfaltowe do izolacji wodochronnej dachów -- Określanie giętkości w niskiej temperaturze
#  			</a>
#  </p>
#  <div class="p4s-clear"></div>
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  					Tytuł w języku angielskim
#  				</span>
#  <a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+1109%3A2013-07E&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">
#  					Flexible sheets for waterproofing - Bitumen sheets for roof waterproofing - Determination of flexibility at low temperature
#  				</a>
#  </p>
#  <div class="p4s-clear"></div>
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  				Status
#  			</span>
#  <span class="p4s-search-results-value actual">
#  				aktualna
#  			</span>
#  </p>
#  <div class="p4s-clear"></div>
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  				Wprowadza
#  			</span>
#  </p>
#  <ul class="p4s-search-results-list-value-container">
#  <li class="p4s-search-results-list-value-element">
#  <span class="p4s-search-results-value">
#  					EN 1109:2013
#  				</span>
#  </li>
#  </ul>
#  <div class="p4s-clear"></div>
#  <p class="p4s-search-results-label-wrapper">
#  <span class="p4s-search-results-label">
#  				Zastępuje
#  			</span>
#  </p>
#  <ul class="p4s-search-results-list-value-container">
#  <li class="p4s-search-results-list-value-element"><a class="p4s-search-results-link" href="https://wiedza.pkn.pl/wyszukiwarka-norm?p_auth=LNbHB2a7&amp;p_p_id=searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_id=column-1&amp;p_p_col_count=1&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_standardNumber=PN-EN+1109%3A2001P&amp;_searchstandards_WAR_p4scustomerpknzwnelsearchstandardsportlet_javax.portlet.action=showStandardDetailsAction">PN-EN 1109:2001
#  				<span style="margin-left: 10px;">
#  					wersja polska
#  				</span>
#  </a></li>
#  </ul>
#  <div class="p4s-clear"></div>
#  </div>]
